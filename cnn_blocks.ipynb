# %%
from tensorflow import keras
from keras.models import Model
from keras.layers import Conv2D, MaxPool2D, Input, Concatenate, Add, Activation

# %% [markdown]
# ### CNN Blocks
#
# We will look at the following implementations:
# 1. **ResNet Block:** The idea behind Residual Blocks is to provide skip connections for gradients to flow through an alternate path such that the performance of a Deep Neural Net is at least good as that of Shallower Net. It adds the input to output of block through an identity function.
#
# 2. **DenseNet Block:** Instead of adding the input as in Residual Block, DenseNet concatenates the input with output of block. Naturally with more blocks, the output size grows enormously making the layer Denser and so, it is not advised to use it on very deep networks.
#
# 3. **Bottleneck Block:** Modifying the Residual Block, it decreases the number of filters intermediately through 1 X 1 convolutions, to reduce number of parameters for subsequent 3 X 3 convolutions. Later, the number of filters are increased back to number of input filters with 1 X 1 convolutions.
#
# 4. **Inception Block:** Merging different operations in parallel by concatenating.
#
# 5. **ResNeXt Block:** Borrowing the idea of parallel processing from inception block, it runs the same operation through parallel paths and the number of parallel paths is called **cardinality**.

# %%
img_size = 256

# %%
def num_parameters(layer, kernel_size, num_inp_channels, num_out_channels):
    if layer=='conv':
        return kernel_size * kernel_size * num_inp_channels * num_out_channels
    if layer=='pool':
        return 0

def conv_output_size(input_dim, kernel_size, stride = 1, padding = 0):
    return (input_dim + 2 * padding - kernel_size) // stride + 1

def pool_output_size(input_dim, pool_size, stride = 1, padding = 0):
    return (input_dim + 2 * padding - pool_size) // stride + 1

# %% [markdown]
# ### ResNet Block

# %%
inp = Input(shape=(img_size, img_size, 64))
x = Conv2D(64, kernel_size=(3,3), padding='same', activation='relu')(inp)
x = Conv2D(64, kernel_size=(3,3), padding='same', activation='relu')(x)
x = Add()([inp, x])
out = Activation('relu')(x)

model = Model(inputs = inp, outputs = out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 6  0           []
#                                 4)]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  36928       ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  add (Add)                      (None, 256, 256, 64  0           ['input_1[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  activation (Activation)        (None, 256, 256, 64  0           ['add[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 73,856
# Trainable params: 73,856
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2022-03-26 14:02:41.337381: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### DenseNet Block

# %%
inp = Input(shape=(img_size, img_size, 64))
x = Conv2D(64, kernel_size=(3,3), padding='same', activation='relu')(inp)
x = Conv2D(64, kernel_size=(3,3), padding='same', activation='relu')(x)
x = Concatenate()([inp, x])
out = Activation('relu')(x)

model = Model(inputs = inp, outputs = out)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 6  0           []
#                                 4)]
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 64  36928       ['input_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 256, 256, 12  0           ['input_2[0][0]',
#                                 8)                                'conv2d_3[0][0]']
#
#  activation_1 (Activation)      (None, 256, 256, 12  0           ['concatenate[0][0]']
#                                 8)
#
# ==================================================================================================
# Total params: 73,856
# Trainable params: 73,856
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Bottleneck Block

# %%
inp = Input(shape=(img_size, img_size, 256))
x = Conv2D(64, kernel_size=(1,1), activation='relu')(inp)
x = Conv2D(64, kernel_size=(3,3), padding='same', activation='relu')(x)
x = Conv2D(256, kernel_size=(1,1), activation='relu')(x)
x = Add()([inp, x])
out = Activation('relu')(x)

model = Model(inputs = inp, outputs = out)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 2  0           []
#                                 56)]
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 64  16448       ['input_3[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 25  16640       ['conv2d_5[0][0]']
#                                 6)
#
#  add_1 (Add)                    (None, 256, 256, 25  0           ['input_3[0][0]',
#                                 6)                                'conv2d_6[0][0]']
#
#  activation_2 (Activation)      (None, 256, 256, 25  0           ['add_1[0][0]']
#                                 6)
#
# ==================================================================================================
# Total params: 70,016
# Trainable params: 70,016
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Inception Block

# %%
inp = Input(shape=(img_size, img_size, 3))
x1 = Conv2D(64, kernel_size=(1,1), activation='relu')(inp)
x2 = Conv2D(64, kernel_size=(1,1), activation='relu')(inp)
x3 = MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(inp)

x1 = Conv2D(32, kernel_size=(3,3), padding='same', activation='relu')(x1)
x2 = Conv2D(32, kernel_size=(5,5), padding='same', activation='relu')(x2)
x3 = Conv2D(32, kernel_size=(1,1), activation='relu')(x3)
x4 = Conv2D(32, kernel_size=(1,1), activation='relu')(inp)

# Depth Concatenation
out = Concatenate(axis=-1)([x1, x2, x3, x4])

model = Model(inputs = inp, outputs = out)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 64  256         ['input_4[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 64  256         ['input_4[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 3)  0           ['input_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 256, 256, 32  18464       ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 256, 256, 32  51232       ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 256, 256, 32  128         ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 256, 256, 32  128         ['input_4[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_9[0][0]',
#                                 8)                                'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]']
#
# ==================================================================================================
# Total params: 70,464
# Trainable params: 70,464
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### ResNeXt Block

# %%
# cardinality - number of parallel paths
num_paths = 32

inp = Input(shape=(img_size, img_size, 256))

features = []
for _ in range(num_paths):
    x = Conv2D(4, kernel_size=(1,1), activation='relu')(inp)
    x = Conv2D(4, kernel_size=(3,3), padding='same', activation='relu')(x)
    x = Conv2D(256, kernel_size=(1,1), activation='relu')(x)
    features.append(x)
x = Add()(features)

out = Add()([x, inp])
model = Model(inputs = inp, outputs = out)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 256, 256, 2  0           []
#                                 56)]
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 256, 256, 4)  1028        ['input_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_16[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_22[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_28[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_34[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_40[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_46[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_49[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_52[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_55[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_58[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_61[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_64[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_67[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_70[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_73[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_76[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_79[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_82[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_85[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_88[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_91[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_94[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 256, 256, 4)  148         ['conv2d_97[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 256, 256, 4)  148         ['conv2d_100[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 256, 256, 4)  148         ['conv2d_103[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 256, 256, 4)  148         ['conv2d_106[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_14[0][0]']
#                                 6)
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_17[0][0]']
#                                 6)
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_20[0][0]']
#                                 6)
#
#  conv2d_24 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_23[0][0]']
#                                 6)
#
#  conv2d_27 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_26[0][0]']
#                                 6)
#
#  conv2d_30 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_29[0][0]']
#                                 6)
#
#  conv2d_33 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_32[0][0]']
#                                 6)
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_35[0][0]']
#                                 6)
#
#  conv2d_39 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_38[0][0]']
#                                 6)
#
#  conv2d_42 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_41[0][0]']
#                                 6)
#
#  conv2d_45 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_44[0][0]']
#                                 6)
#
#  conv2d_48 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_47[0][0]']
#                                 6)
#
#  conv2d_51 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_50[0][0]']
#                                 6)
#
#  conv2d_54 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_53[0][0]']
#                                 6)
#
#  conv2d_57 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_56[0][0]']
#                                 6)
#
#  conv2d_60 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_59[0][0]']
#                                 6)
#
#  conv2d_63 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_62[0][0]']
#                                 6)
#
#  conv2d_66 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_65[0][0]']
#                                 6)
#
#  conv2d_69 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_68[0][0]']
#                                 6)
#
#  conv2d_72 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_71[0][0]']
#                                 6)
#
#  conv2d_75 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_74[0][0]']
#                                 6)
#
#  conv2d_78 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_77[0][0]']
#                                 6)
#
#  conv2d_81 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_80[0][0]']
#                                 6)
#
#  conv2d_84 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_83[0][0]']
#                                 6)
#
#  conv2d_87 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_86[0][0]']
#                                 6)
#
#  conv2d_90 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_89[0][0]']
#                                 6)
#
#  conv2d_93 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_92[0][0]']
#                                 6)
#
#  conv2d_96 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_95[0][0]']
#                                 6)
#
#  conv2d_99 (Conv2D)             (None, 256, 256, 25  1280        ['conv2d_98[0][0]']
#                                 6)
#
#  conv2d_102 (Conv2D)            (None, 256, 256, 25  1280        ['conv2d_101[0][0]']
#                                 6)
#
#  conv2d_105 (Conv2D)            (None, 256, 256, 25  1280        ['conv2d_104[0][0]']
#                                 6)
#
#  conv2d_108 (Conv2D)            (None, 256, 256, 25  1280        ['conv2d_107[0][0]']
#                                 6)
#
#  add_2 (Add)                    (None, 256, 256, 25  0           ['conv2d_15[0][0]',
#                                 6)                                'conv2d_18[0][0]',
#                                                                   'conv2d_21[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_27[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_33[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_39[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_45[0][0]',
#                                                                   'conv2d_48[0][0]',
#                                                                   'conv2d_51[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_57[0][0]',
#                                                                   'conv2d_60[0][0]',
#                                                                   'conv2d_63[0][0]',
#                                                                   'conv2d_66[0][0]',
#                                                                   'conv2d_69[0][0]',
#                                                                   'conv2d_72[0][0]',
#                                                                   'conv2d_75[0][0]',
#                                                                   'conv2d_78[0][0]',
#                                                                   'conv2d_81[0][0]',
#                                                                   'conv2d_84[0][0]',
#                                                                   'conv2d_87[0][0]',
#                                                                   'conv2d_90[0][0]',
#                                                                   'conv2d_93[0][0]',
#                                                                   'conv2d_96[0][0]',
#                                                                   'conv2d_99[0][0]',
#                                                                   'conv2d_102[0][0]',
#                                                                   'conv2d_105[0][0]',
#                                                                   'conv2d_108[0][0]']
#
#  add_3 (Add)                    (None, 256, 256, 25  0           ['add_2[0][0]',
#                                 6)                                'input_5[0][0]']
#
# ==================================================================================================
# Total params: 78,592
# Trainable params: 78,592
# Non-trainable params: 0
# __________________________________________________________________________________________________
